# %%
'''
Extracting features from the rental description and 
analyzing their impact on rental prices
'''
import pandas as pd
import numpy as np
import json

df = pd.read_csv(r"../Data/rentals_description.csv", encoding="utf-8")
print(df.shape)
# Out:
# (833, 2)

# %%
df.head()
# Out:
#                     id                                        description
# 0  1292713234154945280  Enjoy your stay with Panoramic View of the Giz...
# 1  1508718511630646272  Welcome To Marhaba Pyramids View Hotel✨Wake up...
# 2  1297327219631789312  The place is spacious and can accommodate more...
# 3  1606001853199411200  A designer retreat where ancient soul meets mo...
# 4  1314833467096489984  Enjoy stay in Single RoomTHE ROOM FEATURES1 Qu...
