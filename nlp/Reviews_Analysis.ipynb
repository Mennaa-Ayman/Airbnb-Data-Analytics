# %%
'''
Extracting the features from the rental reviews
and analyzing their impact on rental prices
'''
import pandas as pd
import numpy as np
import json

df = pd.read_csv(r"../Data/rentals_reviews.csv", encoding="utf-8")
print(df.shape)
# Out:
# (630, 3)
