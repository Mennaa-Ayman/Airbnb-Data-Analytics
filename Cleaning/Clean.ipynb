# %%
import pandas as pd
import numpy as np
import json

df = pd.read_json(r"../Data/Airbnbdata.json", encoding="utf-8")
print(df.shape)
# Out:
# (833, 8)

# %%
df.head()
# Out:
#                                            thumbnail                   id  \
# 0  https://a0.muscache.com/im/pictures/hosting/Ho...  1292713234154945280
# 1  https://a0.muscache.com/im/pictures/hosting/Ho...  1508718511630646272
# 2  https://a0.muscache.com/im/pictures/hosting/Ho...  1297327219631789312
# 3  https://a0.muscache.com/im/pictures/hosting/Ho...  1606001853199411200
# 4  https://a0.muscache.com/im/pictures/miso/Hosti...  1314833467096489984
#
#                                              title  \
# 0  ETERNA.Suite W Jaccuzi, Pyramids View & Balcony
# 1                                 king khufu suite
# 2                             Akasia Pyramids View
# 3          Mountain Cave | Pyramids View & Jacuzzi
# 4                               Heaven of Pyramids
#
#                                          description  \
# 0  Enjoy your stay with Panoramic View of the Giz...
# 1  Welcome To Marhaba Pyramids View Hotel✨Wake up...
# ...

# %%
# Extract rental id and description, save to new CSV file
rental_info = df[['id', 'description']]
rental_info.to_csv('../Data/rentals_description.csv', index=False, encoding='utf-8')

print(f"Extracted {len(rental_info)} records to rentals_description.csv")
# Out:
# Extracted 833 records to rentals_description.csv
