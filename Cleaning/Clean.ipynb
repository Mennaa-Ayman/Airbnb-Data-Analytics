# %%
import pandas as pd
import json

with open(r"../Data/raw/Airbnbdata.json", encoding="utf-8") as f:
    data = json.load(f)

if isinstance(data, dict):
    data = [data]

df = pd.json_normalize(data)

df.columns = (
    df.columns
    .str.replace('.', '_')  
    .str.lower()             
)

if 'price_price' in df.columns:
    df['price_price'] = (
        df['price_price']
        .astype(str)
        .str.replace('$', '', regex=False)
        
    )

print("Shape:", df.shape)
# Out:
# Shape: (833, 36)

# %%
df.head()
# Out:
#                                            thumbnail                   id  \
# 0  https://a0.muscache.com/im/pictures/hosting/Ho...  1292713234154945394
# 1  https://a0.muscache.com/im/pictures/hosting/Ho...  1508718511630646313
# 2  https://a0.muscache.com/im/pictures/hosting/Ho...  1297327219631789358
# 3  https://a0.muscache.com/im/pictures/hosting/Ho...  1606001853199411128
# 4  https://a0.muscache.com/im/pictures/miso/Hosti...  1314833467096489875
#
#                                              title  \
# 0  ETERNA.Suite W Jaccuzi, Pyramids View & Balcony
# 1                                 king khufu suite
# 2                             Akasia Pyramids View
# 3          Mountain Cave | Pyramids View & Jacuzzi
# 4                               Heaven of Pyramids
#
#                                          description  \
# 0  Enjoy your stay with Panoramic View of the Giz...
# 1  Welcome To Marhaba Pyramids View Hotel✨Wake up...
# ...

# %% [markdown]
# # select the columns import to analysis and drop Not import

# %%
cols_to_keep = [
    "id", "title", "url", "thumbnail",
    "coordinates_latitude", "coordinates_longitude",
    "rating_guestsatisfaction", "rating_reviewscount",
    "rating_accuracy", "rating_cleanliness",
    "rating_value", "rating_location",
    "price_price", "price_originalprice",
    "price_breakdown_specialoffer_price",
    "description"
]

cols_to_keep = [c for c in cols_to_keep if c in df.columns]
df = df[cols_to_keep].copy()

df.head()
# Out:
#                     id                                            title  \
# 0  1292713234154945394  ETERNA.Suite W Jaccuzi, Pyramids View & Balcony
# 1  1508718511630646313                                 king khufu suite
# 2  1297327219631789358                             Akasia Pyramids View
# 3  1606001853199411128          Mountain Cave | Pyramids View & Jacuzzi
# 4  1314833467096489875                               Heaven of Pyramids
#
#                                                  url  \
# 0  https://www.airbnb.com/rooms/12927132341549453...
# 1  https://www.airbnb.com/rooms/15087185116306463...
# 2  https://www.airbnb.com/rooms/12973272196317893...
# 3  https://www.airbnb.com/rooms/16060018531994111...
# 4  https://www.airbnb.com/rooms/13148334670964898...
#
#                                            thumbnail  coordinates_latitude  \
# 0  https://a0.muscache.com/im/pictures/hosting/Ho...             29.973873
# ...

# %% [markdown]
# # rename the columns

# %%
# to rename the columns names
df.rename(columns={
    "coordinates_latitude":               "lat",
    "coordinates_longitude":              "lng",
    "rating_guestsatisfaction":           "rating_overall",
    "rating_reviewscount":                "reviews_count",
    "price_price":                        "price_total",
    "price_originalprice":                "price_original",
    "price_breakdown_specialoffer_price": "discount_amount",
    
}, inplace=True)
df.head()
# Out:
#                     id                                            title  \
# 0  1292713234154945394  ETERNA.Suite W Jaccuzi, Pyramids View & Balcony
# 1  1508718511630646313                                 king khufu suite
# 2  1297327219631789358                             Akasia Pyramids View
# 3  1606001853199411128          Mountain Cave | Pyramids View & Jacuzzi
# 4  1314833467096489875                               Heaven of Pyramids
#
#                                                  url  \
# 0  https://www.airbnb.com/rooms/12927132341549453...
# 1  https://www.airbnb.com/rooms/15087185116306463...
# 2  https://www.airbnb.com/rooms/12973272196317893...
# 3  https://www.airbnb.com/rooms/16060018531994111...
# 4  https://www.airbnb.com/rooms/13148334670964898...
#
#                                            thumbnail        lat        lng  \
# 0  https://a0.muscache.com/im/pictures/hosting/Ho...  29.973873  31.146603
# ...

# %% [markdown]
# # in the first how many Nan values in the all columns

# %%
print(df.isnull().sum())
print("\n")
# Out:
# id                      0
# title                  50
# url                     0
# thumbnail               0
# lat                     2
# lng                     2
# rating_overall        366
# reviews_count         366
# rating_accuracy       366
# rating_cleanliness    366
# rating_value          366
# rating_location       366
# price_total             0
# price_original        530
# discount_amount       606
# description             0
# dtype: int64

# %%
df.columns
# Out:
# Index(['id', 'title', 'url', 'thumbnail', 'lat', 'lng', 'rating_overall',
#        'reviews_count', 'rating_accuracy', 'rating_cleanliness',
#        'rating_value', 'rating_location', 'price_total', 'price_original',
#        'discount_amount'],
#       dtype='str')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 833 entries, 0 to 832
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  833 non-null    str
#  1   title               783 non-null    str
#  2   url                 833 non-null    str
#  3   thumbnail           833 non-null    str
#  4   lat                 831 non-null    float64
#  5   lng                 831 non-null    float64
#  6   rating_overall      467 non-null    float64
#  7   reviews_count       467 non-null    float64
#  8   rating_accuracy     467 non-null    float64
#  9   rating_cleanliness  467 non-null    float64
#  10  rating_value        467 non-null    float64
#  11  rating_location     467 non-null    float64
#  12  price_total         833 non-null    str
#  13  price_original      303 non-null    str
#  14  discount_amount     227 non-null    str
#  15  description         833 non-null    str
# ...

# %% [markdown]
# # filter the data

# %%
df
# Out:
#                       id                                              title  \
# 0    1292713234154945394    ETERNA.Suite W Jaccuzi, Pyramids View & Balcony
# 1    1508718511630646313                                   king khufu suite
# 2    1297327219631789358                               Akasia Pyramids View
# 3    1606001853199411128            Mountain Cave | Pyramids View & Jacuzzi
# 4    1314833467096489875                                 Heaven of Pyramids
# ..                   ...                                                ...
# 828  1230302876047378386                            Luxurious Modern Design
# 829  1393691702395692639          Baron Empain Palace Royal Stay-Heliopolis
# 830  1610456653097966909  A very elegant, beautiful, and unique villa in...
# 831   992199868370320371                          Cozy 3 bedrooms apartment
# 832  1495091463270840616   Luxury Pool View Suite at JW Marriott Residences
#
# ...

# %% [markdown]
# # check the duplicated data

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# # check the NaN Data

# %%
df.isna().sum()
# Out:
# id                      0
# title                  50
# url                     0
# thumbnail               0
# lat                     2
# lng                     2
# rating_overall        366
# reviews_count         366
# rating_accuracy       366
# rating_cleanliness    366
# rating_value          366
# rating_location       366
# price_total             0
# price_original        530
# discount_amount       606
# dtype: int64

# %% [markdown]
# # add has_rating flag according to rating

# %%
df['has_rating'] = df['rating_overall'].notna()

# %% [markdown]
# # cleaning the price data if contain not number

# %%
df['price_total'] = df['price_total'].replace('[^0-9.]', '', regex=True)
df['price_original'] = df['price_original'].replace('[^0-9.]', '', regex=True)
df['discount_amount'] = df['discount_amount'].replace('[^0-9.]', '', regex=True)

# %% [markdown]
# # convert the string to number

# %%
df['price_total'] = pd.to_numeric(df['price_total'], errors='coerce')
df['price_original'] = pd.to_numeric(df['price_original'], errors='coerce')
df['discount_amount'] = pd.to_numeric(df['discount_amount'], errors='coerce')

# %% [markdown]
# # solve the NAN Data

# %%
# title
df['title'] = df['title'].fillna('Unknown')

# prices
df['price_original'] = df['price_original'].fillna(df['price_total'])

# discount
df['discount_amount'] = df['discount_amount'].fillna(
    df['price_original'] - df['price_total']
).clip(lower=0)

# reviews
df['reviews_count'] = df['reviews_count'].fillna(0)

# drop rows without location
df = df.dropna(subset=['lat', 'lng']).copy()

# ratings
rating_cols = [
    'rating_overall',
    'rating_accuracy',
    'rating_cleanliness',
    'rating_value',
    'rating_location'
]

for col in rating_cols:
    df[col] = df[col].fillna(df[col].mean())

# check
print(df[rating_cols].isna().sum())
# Out:
# rating_overall        0
# rating_accuracy       0
# rating_cleanliness    0
# rating_value          0
# rating_location       0
# dtype: int64

# %% [markdown]
# # check the No.of NAN values

# %%
print(df.isna().sum())
df.head()
# Out:
# id                    0
# title                 0
# url                   0
# thumbnail             0
# lat                   0
# lng                   0
# rating_overall        0
# reviews_count         0
# rating_accuracy       0
# rating_cleanliness    0
# rating_value          0
# rating_location       0
# price_total           0
# price_original        0
# discount_amount       0
# description           0
# has_rating            0
# dtype: int64
#                     id                                            title  \
# 0  1292713234154945394  ETERNA.Suite W Jaccuzi, Pyramids View & Balcony
# 1  1508718511630646313                                 king khufu suite
# 2  1297327219631789358                             Akasia Pyramids View
# 3  1606001853199411128          Mountain Cave | Pyramids View & Jacuzzi
# 4  1314833467096489875                               Heaven of Pyramids
#
#                                                  url  \
# ...

# %% [markdown]
# # convert the price from string data type to float data type

# %%
cols = [
    'rating_overall',
    'reviews_count',
    'rating_accuracy',
    'rating_cleanliness',
    'rating_value',
    'rating_location',
    'price_total',
    'price_original',
    'discount_amount'
]

for col in cols:
    df[col] = pd.to_numeric(df[col], errors='coerce')

# %% [markdown]
# # save the cleaning data in csv file

# %%
df.to_csv("../Data/clean/airbnb_cleaningdata.csv", index=False, encoding="utf-8-sig")

# %% [markdown]
# # convert the data to Json file

# %%
df.to_json("../Data/clean/airbnbdata.json", orient="records", indent=4, force_ascii=False)
